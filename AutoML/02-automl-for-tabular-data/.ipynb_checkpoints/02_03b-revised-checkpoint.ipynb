# %%
import numpy as np
from autogluon.tabular import TabularDataset, TabularPredictor
from autogluon.core.metrics import make_scorer
from sklearn.model_selection import train_test_split

# %%
train_data = TabularDataset('../01-machine-learning-recap/data/train_data.csv')

# %%
train_data.head()
# Out:
#   Customer Id  YearOfObservation  Insured_Period  Residential  \
# 0      H14663               2013             1.0            0
# 1       H2037               2015             1.0            0
# 2       H3802               2014             1.0            0
# 3       H3834               2013             1.0            0
# 4       H5053               2014             1.0            0
#
#   Building_Painted Building_Fenced Garden Settlement  Building Dimension  \
# 0                N               V      V          U               290.0
# 1                V               N      O          R               490.0
# 2                N               V      V          U               595.0
# 3                V               V      V          U              2840.0
# 4                V               N      O          R               680.0
#
#    Building_Type  Date_of_Occupancy NumberOfWindows Geo_Code  Claim
# 0              1             1960.0               .     1053      0
# 1              1             1850.0               4     1053      0
# 2              1             1960.0               .     1053      0
# 3              1             1960.0               .     1053      0
# 4              1             1800.0               3     1053      0

# %%
train, test = train_test_split(train_data, test_size=0.3, shuffle=True)

# %%
EVAL_METRIC = "f1"
SAVE_PATH = "AutoGluonModels_improved"   # Trained models will be saved here
LABEL = "Claim"

# %% [markdown]
# ## Improving your AutoGluon Model

# %% [markdown]
# ### 1. Via Feature Engineering

# %%
train["age_of_building"] = train["YearOfObservation"] - train["Date_of_Occupancy"]
test["age_of_building"] = test["YearOfObservation"] - test["Date_of_Occupancy"]

train["YearOfObservation"] = train["YearOfObservation"].astype("category")
test["YearOfObservation"] = test["YearOfObservation"].astype("category")

# %% [markdown]
# ### 2. Use the Right Preset & refit_full

# %%
predictor = TabularPredictor(label=LABEL, path=SAVE_PATH, eval_metric=EVAL_METRIC)

# %%
predictor = predictor.fit(
    train, 
    presets=["best_quality"], 
    time_limit=100, 
    refit_full="best"
)
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=0, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 100s
# AutoGluon will save models to "AutoGluonModels_improved/"
# AutoGluon Version:  0.8.2
# Python Version:     3.9.7
# Operating System:   Darwin
# Platform Machine:   x86_64
# Platform Version:   Darwin Kernel Version 22.1.0: Sun Oct  9 20:15:09 PDT 2022; root:xnu-8792.41.9~2/RELEASE_ARM64_T6000
# Disk Space Avail:   189.54 GB / 494.38 GB (38.3%)
# Train Data Rows:    5012
# Train Data Columns: 14
# Label Column: Claim
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    793.37 MB
# 	Train Data (Original)  Memory Usage: 2.33 MB (0.3% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 2): ['Customer Id', 'Settlement']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 2 | ['Customer Id', 'Settlement']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['YearOfObservation']
# 		('float', [])    : 4 | ['Insured_Period', 'Building Dimension', 'Date_of_Occupancy', 'age_of_building']
# 		('int', [])      : 2 | ['Residential', 'Building_Type']
# 		('object', [])   : 5 | ['Building_Painted', 'Building_Fenced', 'Garden', 'NumberOfWindows', 'Geo_Code']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 4 | ['YearOfObservation', 'Garden', 'NumberOfWindows', 'Geo_Code']
# 		('float', [])     : 4 | ['Insured_Period', 'Building Dimension', 'Date_of_Occupancy', 'age_of_building']
# 		('int', [])       : 1 | ['Building_Type']
# 		('int', ['bool']) : 3 | ['Residential', 'Building_Painted', 'Building_Fenced']
# 	0.3s = Fit runtime
# 	12 features in original data used to generate 12 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.24 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.3s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'f1'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 99.7s of the 99.7s of remaining time.
# 	0.2875	 = Validation score   (f1)
# 	3.38s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 96.25s of the 96.25s of remaining time.
# /Users/robertandrewstevens/opt/anaconda3/lib/python3.9/site-packages/daal4py/sklearn/neighbors/_base.py:357: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   result = super(NeighborsBase, self)._fit(X, y)
# 	0.2989	 = Validation score   (f1)
# 	0.17s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 96.05s of the 96.05s of remaining time.
# Will use sequential fold fitting strategy because import of ray failed. Reason: ray is required to train folds in parallel. A quick tip is to install via `pip install ray==2.2.0`, or use sequential fold fitting by passing `sequential_local` to `ag_args_ensemble` when calling tabular.fitFor example: `predictor.fit(..., ag_args_ensemble={'fold_fitting_strategy': 'sequential_local'})`
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Ran out of time, early stopping on iteration 288. Best iteration is:
# 	[216]	valid_set's binary_logloss: 0.477771	valid_set's f1: 0.350515
# 	Ran out of time, early stopping on iteration 335. Best iteration is:
# 	[269]	valid_set's binary_logloss: 0.531139	valid_set's f1: 0.358491
# 	Ran out of time, early stopping on iteration 326. Best iteration is:
# 	[297]	valid_set's binary_logloss: 0.521388	valid_set's f1: 0.29703
# 	Ran out of time, early stopping on iteration 387. Best iteration is:
# 	[381]	valid_set's binary_logloss: 0.515162	valid_set's f1: 0.373333
# 	Ran out of time, early stopping on iteration 412. Best iteration is:
# 	[376]	valid_set's binary_logloss: 0.541032	valid_set's f1: 0.270531
# 	Ran out of time, early stopping on iteration 770. Best iteration is:
# 	[748]	valid_set's binary_logloss: 0.517236	valid_set's f1: 0.4
# 	0.3489	 = Validation score   (f1)
# 	84.46s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 11.35s of the 11.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	Ran out of time, early stopping on iteration 53. Best iteration is:
# 	[53]	valid_set's binary_logloss: 0.474632	valid_set's f1: 0.336842
# 	Ran out of time, early stopping on iteration 52. Best iteration is:
# 	[51]	valid_set's binary_logloss: 0.495238	valid_set's f1: 0.310881
# 	Ran out of time, early stopping on iteration 47. Best iteration is:
# 	[47]	valid_set's binary_logloss: 0.496246	valid_set's f1: 0.253968
# 	Ran out of time, early stopping on iteration 62. Best iteration is:
# 	[43]	valid_set's binary_logloss: 0.484755	valid_set's f1: 0.341709
# 	Ran out of time, early stopping on iteration 72. Best iteration is:
# 	[68]	valid_set's binary_logloss: 0.515275	valid_set's f1: 0.235897
# 	Ran out of time, early stopping on iteration 57. Best iteration is:
# 	[43]	valid_set's binary_logloss: 0.474737	valid_set's f1: 0.39
# 	Ran out of time, early stopping on iteration 65. Best iteration is:
# 	[57]	valid_set's binary_logloss: 0.466262	valid_set's f1: 0.31746
# 	Ran out of time, early stopping on iteration 73. Best iteration is:
# 	[51]	valid_set's binary_logloss: 0.502569	valid_set's f1: 0.331658
# 	0.3153	 = Validation score   (f1)
# 	10.86s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 0.37s of the 0.37s of remaining time.
# 	0.3113	 = Validation score   (f1)
# 	0.39s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 99.7s of the -0.27s of remaining time.
# 	0.3489	 = Validation score   (f1)
# 	0.92s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 101.2s ... Best model: "WeightedEnsemble_L2"
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	5.23s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	0.92s	 = Training   runtime
# Refit complete, total runtime = 5.33s
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutoGluonModels_improved/")

# %%
predictor.leaderboard(extra_info=True, silent=True).head()
# Out:
#                      model  score_val  pred_time_val   fit_time  \
# 0        LightGBMXT_BAG_L1   0.348921       0.086342  84.461349
# 1      WeightedEnsemble_L2   0.348921       0.094679  85.377020
# 2          LightGBM_BAG_L1   0.315315       0.050487  10.859208
# 3  RandomForestGini_BAG_L1   0.311321       0.186257   0.388448
# 4    KNeighborsDist_BAG_L1   0.298897       0.010243   0.165230
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.086342          84.461349            1       True
# 1                0.008337           0.915670            2       True
# 2                0.050487          10.859208            1       True
# 3                0.186257           0.388448            1       True
# 4                0.010243           0.165230            1       True
#
#    fit_order  num_features  ...  \
# 0          3            12  ...
# 1          6             1  ...
# 2          4            12  ...
# 3          5            12  ...
# 4          2             5  ...
#
#                                      hyperparameters  hyperparameters_fit  \
# 0  {'use_orig_features': True, 'max_base_models':...                   {}
# 1  {'use_orig_features': False, 'max_base_models'...                   {}
# 2  {'use_orig_features': True, 'max_base_models':...                   {}
# 3  {'use_orig_features': True, 'max_base_models':...                   {}
# 4  {'use_orig_features': True, 'max_base_models':...                   {}
#
#                                          ag_args_fit  \
# 0  {'max_memory_usage_ratio': 1.0, 'max_time_limi...
# 1  {'max_memory_usage_ratio': 1.0, 'max_time_limi...
# 2  {'max_memory_usage_ratio': 1.0, 'max_time_limi...
# 3  {'max_memory_usage_ratio': 1.0, 'max_time_limi...
# 4  {'max_memory_usage_ratio': 1.0, 'max_time_limi...
#
#                                             features  compile_time  \
# 0  [Geo_Code, Insured_Period, Building_Type, age_...          None
# 1                                [LightGBMXT_BAG_L1]          None
# 2  [Geo_Code, Insured_Period, Building_Type, age_...          None
# 3  [Geo_Code, Insured_Period, Building_Type, age_...          None
# 4  [Insured_Period, age_of_building, Building_Typ...          None
#
#                                child_hyperparameters  \
# 0       {'learning_rate': 0.05, 'extra_trees': True}
# 1                             {'ensemble_size': 100}
# 2                            {'learning_rate': 0.05}
# 3  {'n_estimators': 300, 'max_leaf_nodes': 15000,...
# 4                            {'weights': 'distance'}
#
#    child_hyperparameters_fit  \
# 0   {'num_boost_round': 325}
# 1       {'ensemble_size': 1}
# 2    {'num_boost_round': 52}
# 3      {'n_estimators': 300}
# 4                         {}
#
#                                    child_ag_args_fit            ancestors  \
# 0  {'max_memory_usage_ratio': 1.0, 'max_time_limi...                   []
# 1  {'max_memory_usage_ratio': 1.0, 'max_time_limi...  [LightGBMXT_BAG_L1]
# 2  {'max_memory_usage_ratio': 1.0, 'max_time_limi...                   []
# 3  {'max_memory_usage_ratio': 1.0, 'max_time_limi...                   []
# 4  {'max_memory_usage_ratio': 1.0, 'max_time_limi...                   []
#
#              descendants
# 0  [WeightedEnsemble_L2]
# 1                     []
# 2                     []
# 3                     []
# 4                     []
#
# [5 rows x 30 columns]

# %% [markdown]
# ### 3. Via CustomMetrics

# %%
fp_cost = 1000  # Admin fees spent to investigate potential insurance claim
fn_cost = 10000 # Average insurance claim made
tp_cost = 1000 # Admin fees spent to investigate potential insurance claim
tn_cost = 0

# %%
def cost_fn(y_true, y_prob):
    tp = np.where((y_prob >= 0.7) & (y_true==1), tp_cost, 0)
    fp = np.where((y_prob >= 0.7) & (y_true==0), fp_cost, 0)
    tn = np.where((y_prob < 0.7) & (y_true==0), tn_cost, 0)
    fn = np.where((y_prob < 0.7) & (y_true==1), fn_cost, 0)
    return np.sum([tp,fp,tn,fn])

# %%
op_scorer = make_scorer(
    name="operating_cost",
    score_func=cost_fn,
    greater_is_better=False,
    needs_proba=True
)

# %%
predictor.leaderboard(test, extra_metrics=[op_scorer], silent=True).head()
# Out:
#                       model  score_test  operating_cost  score_val  \
# 0   RandomForestGini_BAG_L1    0.353261        -4517000   0.311321
# 1         LightGBMXT_BAG_L1    0.337143        -4534000   0.348921
# 2       WeightedEnsemble_L2    0.337143        -4534000   0.348921
# 3    LightGBMXT_BAG_L1_FULL    0.332386        -4514000        NaN
# 4  WeightedEnsemble_L2_FULL    0.332386        -4514000        NaN
#
#    pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0        0.095755       0.186257   0.388448                 0.095755
# 1        0.136519       0.086342  84.461349                 0.136519
# 2        0.138251       0.094679  85.377020                 0.001732
# 3        0.018675            NaN   5.234116                 0.018675
# 4        0.020068            NaN   6.149786                 0.001393
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.186257           0.388448            1       True
# 1                0.086342          84.461349            1       True
# 2                0.008337           0.915670            2       True
# 3                     NaN           5.234116            1       True
# 4                     NaN           0.915670            2       True
#
#    fit_order
# 0          5
# 1          3
# 2          6
# 3          7
# 4          8
